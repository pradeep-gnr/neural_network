# %%
"""
    I used https://github.com/NSAryan12/nn-from-scratch/blob/master/nn-from-scratch.ipynb as a basis for this notebook.
    But the neural network class that I am testing here is my implementation.
"""
# Package imports
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# Generate a dataset and plot it
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %%
# Let us try to use a logisitc regression classifier.
# Train the logistic regeression classifier
clf = sklearn.linear_model.LogisticRegressionCV()
clf.fit(X, y)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=None, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
# Helper function to plot a decision boundary.
# If you don't fully understand this function don't worry, it just generates the contour plot below.
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    print Z.shape
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: clf.predict(x))
plt.title("Logistic Regression")
# Out:
# (151208,)

# %%
from neural_network import NeuralNetwork
nn = NeuralNetwork(X,y, hidden_layers=2, n_iterations=400)
nn.train()
# Out:
# Epoch : 1
# Epoch: 1, Error: 0.5
# Epoch : 2
# Epoch: 2, Error: 0.5
# Epoch : 3
# Epoch: 3, Error: 0.5
# Epoch : 4
# Epoch: 4, Error: 0.5
# Epoch : 5
# Epoch: 5, Error: 0.5
# Epoch : 6
# Epoch: 6, Error: 0.5
# Epoch : 7
# Epoch: 7, Error: 0.5
# Epoch : 8
# Epoch: 8, Error: 0.5
# Epoch : 9
# Epoch: 9, Error: 0.5
# Epoch : 10
# Epoch: 10, Error: 0.5
# Epoch : 11
# Epoch: 11, Error: 0.5
# Epoch : 12
# Epoch: 12, Error: 0.5
# Epoch : 13
# Epoch: 13, Error: 0.5
# Epoch : 14
# Epoch: 14, Error: 0.5
# Epoch : 15
# Epoch: 15, Error: 0.5
# Epoch : 16
# Epoch: 16, Error: 0.495
# Epoch : 17
# Epoch: 17, Error: 0.455
# Epoch : 18
# Epoch: 18, Error: 0.355
# Epoch : 19
# Epoch: 19, Error: 0.28
# Epoch : 20
# Epoch: 20, Error: 0.215
# Epoch : 21
# Epoch: 21, Error: 0.205
# Epoch : 22
# Epoch: 22, Error: 0.17
# Epoch : 23
# Epoch: 23, Error: 0.17
# Epoch : 24
# Epoch: 24, Error: 0.145
# Epoch : 25
# Epoch: 25, Error: 0.145
# Epoch : 26
# Epoch: 26, Error: 0.15
# Epoch : 27
# ...

# %%
# Helper function to plot a decision boundary.
# If you don't fully understand this function don't worry, it just generates the contour plot below.
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = np.array(Z)
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)
plot_decision_boundary(lambda x: nn.predict(x))
plt.title("Decision Boundary for hidden layer size 2")

# %%
# Hidden layer size of 10
from neural_network import NeuralNetwork
nn_2 = NeuralNetwork(X,y, hidden_layers=10, n_iterations=400)
nn_2.train()
# Out:
# Epoch : 1
# Epoch: 1, Error: 0.15
# Epoch : 2
# Epoch: 2, Error: 0.18
# Epoch : 3
# Epoch: 3, Error: 0.17
# Epoch : 4
# Epoch: 4, Error: 0.145
# Epoch : 5
# Epoch: 5, Error: 0.15
# Epoch : 6
# Epoch: 6, Error: 0.155
# Epoch : 7
# Epoch: 7, Error: 0.155
# Epoch : 8
# Epoch: 8, Error: 0.145
# Epoch : 9
# Epoch: 9, Error: 0.145
# Epoch : 10
# Epoch: 10, Error: 0.155
# Epoch : 11
# Epoch: 11, Error: 0.155
# Epoch : 12
# Epoch: 12, Error: 0.15
# Epoch : 13
# Epoch: 13, Error: 0.155
# Epoch : 14
# Epoch: 14, Error: 0.16
# Epoch : 15
# Epoch: 15, Error: 0.155
# Epoch : 16
# Epoch: 16, Error: 0.155
# Epoch : 17
# Epoch: 17, Error: 0.15
# Epoch : 18
# Epoch: 18, Error: 0.15
# Epoch : 19
# Epoch: 19, Error: 0.15
# Epoch : 20
# Epoch: 20, Error: 0.145
# Epoch : 21
# Epoch: 21, Error: 0.145
# Epoch : 22
# Epoch: 22, Error: 0.145
# Epoch : 23
# Epoch: 23, Error: 0.145
# Epoch : 24
# Epoch: 24, Error: 0.145
# Epoch : 25
# Epoch: 25, Error: 0.145
# Epoch : 26
# Epoch: 26, Error: 0.145
# Epoch : 27
# ...

# %%
plot_decision_boundary(lambda x: nn_2.predict(x))
plt.title("Decision Boundary for hidden layer size 10")

# %%
# Hidden layer size of 20
from neural_network import NeuralNetwork
nn_3 = NeuralNetwork(X,y, hidden_layers=20, n_iterations=400)
nn_3.train()
# Out:
# Epoch : 1
# Epoch: 1, Error: 0.49
# Epoch : 2
# Epoch: 2, Error: 0.19
# Epoch : 3
# Epoch: 3, Error: 0.17
# Epoch : 4
# Epoch: 4, Error: 0.145
# Epoch : 5
# Epoch: 5, Error: 0.15
# Epoch : 6
# Epoch: 6, Error: 0.155
# Epoch : 7
# Epoch: 7, Error: 0.15
# Epoch : 8
# Epoch: 8, Error: 0.15
# Epoch : 9
# Epoch: 9, Error: 0.15
# Epoch : 10
# Epoch: 10, Error: 0.145
# Epoch : 11
# Epoch: 11, Error: 0.145
# Epoch : 12
# Epoch: 12, Error: 0.15
# Epoch : 13
# Epoch: 13, Error: 0.15
# Epoch : 14
# Epoch: 14, Error: 0.15
# Epoch : 15
# Epoch: 15, Error: 0.15
# Epoch : 16
# Epoch: 16, Error: 0.145
# Epoch : 17
# Epoch: 17, Error: 0.145
# Epoch : 18
# Epoch: 18, Error: 0.145
# Epoch : 19
# Epoch: 19, Error: 0.145
# Epoch : 20
# Epoch: 20, Error: 0.145
# Epoch : 21
# Epoch: 21, Error: 0.145
# Epoch : 22
# Epoch: 22, Error: 0.145
# Epoch : 23
# Epoch: 23, Error: 0.145
# Epoch : 24
# Epoch: 24, Error: 0.145
# Epoch : 25
# Epoch: 25, Error: 0.145
# Epoch : 26
# Epoch: 26, Error: 0.145
# Epoch : 27
# ...

# %%
plot_decision_boundary(lambda x: nn_3.predict(x))
plt.title("Decision Boundary for hidden layer size 20")
